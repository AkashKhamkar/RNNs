# %%
from __future__ import print_function
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN
from keras.models import Sequential
#from keras.utils.visualize_util import plot
import numpy as np

# %%
fin = open("11-0.txt",'rb')
lines = []
for line in fin:
    line = line.strip().lower()
    line = line.decode("ascii","ignore")
    if len(line) == 0:
        continue
    lines.append(line)
fin.close()
text = " ".join(lines)

# %%
chars = set([c for c in text])
nb_chars = len(chars)
char2index = dict((c, i) for i, c in enumerate(chars))
index2char = dict((i, c) for i, c in enumerate(chars))

# %%
SEQLEN = 10
STEP = 1

input_chars = []
label_chars = []
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i:i + SEQLEN])
    label_chars.append(text[i + SEQLEN])

# %%
X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)

for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
        y[i ,char2index[label_chars[i]]] = 1

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 128
NUM_ITERATIONS = 100
NUM_EPOCHS_PER_ITERATIONS = 1
NUM_PREDS_PER_EPOCH = 100

model = Sequential()
model.add(SimpleRNN(HIDDEN_SIZE, return_sequences=False, input_shape=(SEQLEN, nb_chars), unroll=True))
model.add(Dense(nb_chars))
model.add(Activation("softmax"))

model.compile(loss="categorical_crossentropy", optimizer="rmsprop")

# %%
for iteration in range(NUM_ITERATIONS):
    print("=" * 50)
    print("Iteration #: %d" %(iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATIONS)
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print("Generating from seed: %s" %(test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end="")
        # MOVE FORWARD WITH TEST_CHARS + YPRED
        test_chars  =  test_chars[1:] + ypred
print()
# Out:
# ==================================================
# Iteration #: 0
# Epoch 1/1
# 158773/158773 [==============================] - 6s 41us/step - loss: 2.3315
# Generating from seed: tone, and
# tone, and the said the said the said the said the said the said the said the said the said the said the said t==================================================
# Iteration #: 1
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 2.0467
# Generating from seed: on is subj
# on is subjest ghe hat in the said the doon the was she said the doon the was she said the doon the was she sai==================================================
# Iteration #: 2
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.9459
# Generating from seed: of the hou
# of the houre said the said the said the said the said the said the said the said the said the said the said th==================================================
# Iteration #: 3
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.8652
# Generating from seed: uickly tha
# uickly that in the doon the was the dont of the mound the gotent of the mound the gotent of the mound the gote==================================================
# Iteration #: 4
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.7976
# Generating from seed: ssed; it w
# ssed; it was the doon the doon the doon the doon the doon the doon the doon the doon the doon the doon the doo==================================================
# Iteration #: 5
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.7433
# Generating from seed:  walk a li
#  walk a little said the cores and the could the comer at the could the comer at the could the comer at the cou==================================================
# Iteration #: 6
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.6968
# Generating from seed: peared to
# peared to be a little to the project gutenberg-tm the project gutenberg-tm the project gutenberg-tm the projec==================================================
# Iteration #: 7
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.6572
# Generating from seed: located in
# located in a little said the dormouse, and the the the the the the the the the the the the the the the the the==================================================
# Iteration #: 8
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.6240
# Generating from seed: know-- she
# know-- she said the dormouse, who had so the satter said the dormouse, who had so the satter said the dormouse==================================================
# Iteration #: 9
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.5946
# Generating from seed: terms of t
# terms of the cous with the cat out of the cous with the cat out of the cous with the cat out of the cous with ==================================================
# Iteration #: 10
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.5699
# Generating from seed: k any more
# k any more the ream out of the repting to the remerted the word into the rabbit a fit of the repting to the re==================================================
# Iteration #: 11
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.5474
# Generating from seed: mingo and
# mingo and alice was she was a little she was a little she was a little she was a little she was a little she w==================================================
# Iteration #: 12
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.5280
# Generating from seed:  worse. yo
#  worse. you may not it was out of the project gutenberg-tm electronic work are off it was not a little began t==================================================
# Iteration #: 13
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.5105
# Generating from seed: t, as she
# t, as she was to her here. alice as agree to alice as agree to alice as agree to alice as agree to alice as ag==================================================
# Iteration #: 14
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.4952
# Generating from seed: t, if you
# t, if you she should be and was got to say of the could not the cook had the works and a little she was got to==================================================
# Iteration #: 15
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4814
# Generating from seed: make perso
# make persont to the work and so the right some of the the the same a little said to herself, and the hatter. a==================================================
# Iteration #: 16
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4698
# Generating from seed:  and menti
#  and menting the could not they were said the could not they were said the could not they were said the could ==================================================
# Iteration #: 17
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4578
# Generating from seed: ugh this w
# ugh this was a little she was a little she was a little she was a little she was a little she was a little she==================================================
# Iteration #: 18
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4479
# Generating from seed: nd dont be
# nd dont be nermed to seemed to be the had been alice, and said to the whole she had been alice, and said to th==================================================
# Iteration #: 19
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4380
# Generating from seed: copyright
# copyright to the gryphon in a long had to the gryphon in a long had to the gryphon in a long had to the grypho==================================================
# Iteration #: 20
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4284
# Generating from seed: . well, i
# . well, i shall she was the was in a herestion of the three gardeners at all the caterpillars and all the time==================================================
# Iteration #: 21
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4205
# Generating from seed: y fur and
# y fur and so one of the little site the queen the door and so good a little she had said to the door and so go==================================================
# Iteration #: 22
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4130
# Generating from seed: ased. now
# ased. now i dont to be as she went on the whole party it was no know what they would be got to herself the wor==================================================
# Iteration #: 23
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.4066
# Generating from seed:  and behin
#  and behind the poor little thing as i know the caterpillar sead the mock turtle was the pabbit alice said to ==================================================
# Iteration #: 24
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.4010
# Generating from seed:  outside t
#  outside the the court what the door and the march hare as she was i have a fear soover the dormouse she was i==================================================
# Iteration #: 25
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3928
# Generating from seed:  she began
#  she began to the project gutenberg-tm electronic work and said to herself the project gutenberg-tm electronic==================================================
# Iteration #: 26
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3872
# Generating from seed:  you agree
#  you agreement and contatter with the right to herself the first the rabbit agree to herself the first the rab==================================================
# Iteration #: 27
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3815
# Generating from seed: 1500 west,
# 1500 west, and the dormouse of the same she had a little shrink the same she had a little shrink the same she ==================================================
# Iteration #: 28
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.3767
# Generating from seed: some more
# some more to get the time the poor caner to alice the tried the tried the tried the tried the tried the tried ==================================================
# Iteration #: 29
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3723
# Generating from seed: gutenberg-
# gutenberg-tm electronic works in a long the way side and the white rabbit as she was to the white rabbit as sh==================================================
# Iteration #: 30
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3669
# Generating from seed: so extreme
# so extremely repeated to the dormouse the mock turtle and alice to the thing at the whole the dormouse the moc==================================================
# Iteration #: 31
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3628
# Generating from seed: e sense in
# e sense in the seact of a look of the the the sook of the the the sook of the the the sook of the the the sook==================================================
# Iteration #: 32
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3587
# Generating from seed: a full ref
# a full refuling the project gutenberg-tm electronic works in the same the rest of course, the mock turtle in t==================================================
# Iteration #: 33
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3544
# Generating from seed:  goldfish
#  goldfish about the dormouse should herself about it was so ortation about and drow all read at the end of she==================================================
# Iteration #: 34
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3500
# Generating from seed:  the poor
#  the poor cat no to the court went on in a herestiful to see she said the caterpillar seemon the caterpillar s==================================================
# Iteration #: 35
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3463
# Generating from seed:  without n
#  without nowhanty, said the king so got and she said to her head some of the courting at the hatter with the c==================================================
# Iteration #: 36
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3430
# Generating from seed: arious pre
# arious present deat or datch in the mort the door a little shriek of the court way to the time the mock turtle==================================================
# Iteration #: 37
# Epoch 1/1
# 158773/158773 [==============================] - 6s 41us/step - loss: 1.3395
# Generating from seed:  sense, th
#  sense, the mock turtle was to the thing it was and you know the mock turtle was to the thing it was and you k==================================================
# Iteration #: 38
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3365
# Generating from seed: sion of th
# sion of the same thing of the same thing of the same thing of the same thing of the same thing of the same thi==================================================
# Iteration #: 39
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3334
# Generating from seed: got so clo
# got so close to her eyely upor she had got up and the caterpillar siderarys are of expeating the project guten==================================================
# Iteration #: 40
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3304
# Generating from seed: not, said
# not, said the mock turtle we white rabbit before the more the little grow not a sort of the courted her like t==================================================
# Iteration #: 41
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3267
# Generating from seed: rs, in gre
# rs, in great doch the mock turtle was so she had been of the the three gardeners of the gryphon were the three==================================================
# Iteration #: 42
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3247
# Generating from seed: ence insta
# ence install, i wonder what they had the mock turtle in a very much a little she was in the mouse the rabbit a==================================================
# Iteration #: 43
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3221
# Generating from seed: nicely by
# nicely by the with the right the gryphon, and what a strers of the gryphon, and what a strers of the gryphon, ==================================================
# Iteration #: 44
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3200
# Generating from seed: ded tone:
# ded tone: the duchess said to herself this was nothing she said to herself this was nothing she said to hersel==================================================
# Iteration #: 45
# Epoch 1/1
# 158773/158773 [==============================] - 6s 40us/step - loss: 1.3166
# Generating from seed: he air. ev
# he air. ever side of the court was some of the court was some of the court was some of the court was some of t==================================================
# Iteration #: 46
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3143
# Generating from seed: hedgehogs
# hedgehogs who gade how do all the mort the same thing she said to herself, i sure it was a low the poor little==================================================
# Iteration #: 47
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3125
# Generating from seed:  party wer
#  party were she was to the time the mock turtle was to the time the mock turtle was to the time the mock turtl==================================================
# Iteration #: 48
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.3101
# Generating from seed: y tears. n
# y tears. no silenting of the terms of this agreement things a this alice the door any way put it was the remar==================================================
# Iteration #: 49
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3078
# Generating from seed: ; so, afte
# ; so, after her of the cook the tried to see sheated alice the mock turtle with the mock turtle with the mock ==================================================
# Iteration #: 50
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3064
# Generating from seed: berg-tm is
# berg-tm ise to be for so she said to herself, i shall the time, said alice, and she said to herself, i shall t==================================================
# Iteration #: 51
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3041
# Generating from seed: g. the jud
# g. the jud off the court and completes the little good the hatter wet know the little good the hatter wet know==================================================
# Iteration #: 52
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.3029
# Generating from seed: o, and in
# o, and in the stight rabbit asked to see she was so reall her heard a little she had that it was got and she h==================================================
# Iteration #: 53
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.3012
# Generating from seed:  again, it
#  again, it was and distribute the gryphon, and the mock turtle went on experses, and the mock turtle went on e==================================================
# Iteration #: 54
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2985
# Generating from seed: k, and mad
# k, and made a come of the court and with a might alice could not the door alice went on the eart had any dista==================================================
# Iteration #: 55
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2980
# Generating from seed: he moment
# he moment alice, and she said to herself, and the mock turtle in a peares that it was a little thing she said ==================================================
# Iteration #: 56
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.2948
# Generating from seed: e trials o
# e trials of the court and and done what the doun and alice to see she was to the tried to her explaning tone w==================================================
# Iteration #: 57
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2946
# Generating from seed:  gutenberg
#  gutenberg-tm trid the dormouse said to herself to the tried to find her ever sigg finished the foundation and==================================================
# Iteration #: 58
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2924
# Generating from seed: for some t
# for some the tried herself to herself, i shall seem to alice was so the this agreement a long a grow which she==================================================
# Iteration #: 59
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2905
# Generating from seed: ought alic
# ought alice again, and the mouse was said, and she had not a thing with her head about the states, said the mo==================================================
# Iteration #: 60
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2888
# Generating from seed: an whistli
# an whistlies and distributing to herself, in the state what the door and her head some of the project gutenber==================================================
# Iteration #: 61
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2874
# Generating from seed: s i do, sa
# s i do, said the caterpillar soon and the more the project gutenberg-tm electronic works in the project gutenb==================================================
# Iteration #: 62
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2861
# Generating from seed: was a brig
# was a bright tea set for a mont a little this floors a little this floors a little this floors a little this f==================================================
# Iteration #: 63
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2848
# Generating from seed:  was bill,
#  was bill, the poor alice, and she was a low the pappy sat it was a low the pappy sat it was a low the pappy s==================================================
# Iteration #: 64
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2839
# Generating from seed: hich was s
# hich was said the dormouse should be like a thing when i tely as it was the rabbit again, and the door and she==================================================
# Iteration #: 65
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2827
# Generating from seed: o you? im
# o you? im the dormouse said to herself, i shall he went on the project gutenberg-tm electronic work to she had==================================================
# Iteration #: 66
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2812
# Generating from seed:  the owner
#  the owner of the court and the mock turtle in the door anything they had seemed to herself, and the hatter. a==================================================
# Iteration #: 67
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2797
# Generating from seed: e no mice
# e no mice that the first the gryphon replied in a can of the gryphon replied in a can of the gryphon replied i==================================================
# Iteration #: 68
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2791
# Generating from seed: aid the gr
# aid the gryphon. alice said the mock turtle in a hereed at the project gutenberg-tm electronic works in her si==================================================
# Iteration #: 69
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2775
# Generating from seed: im afraid,
# im afraid, and was going to the project gutenberg-tm electronic works in the project gutenberg-tm electronic w==================================================
# Iteration #: 70
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2775
# Generating from seed: alice did
# alice did not like to the project gutenberg-tm electronic work to see herself about the project gutenberg-tm e==================================================
# Iteration #: 71
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2759
# Generating from seed:  in the la
#  in the last the door a cont project gutenberg-tm electronic works in her face to the door a cont project gute==================================================
# Iteration #: 72
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2747
# Generating from seed:  under whi
#  under which she had not like to alice a dear. alice did not like to alice a dear. alice did not like to alice==================================================
# Iteration #: 73
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2738
# Generating from seed: e same ton
# e same tone with the trees or dear soon as she thought the work of any sure, she said to herself, in the same ==================================================
# Iteration #: 74
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2728
# Generating from seed: m to you,
# m to you, and the hatter was out the dormouse it in a hery that it was not at the foother down the project gut==================================================
# Iteration #: 75
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2724
# Generating from seed: s for brin
# s for bring her alice did not like the little grow the long her know what the trees and a room him nothing of ==================================================
# Iteration #: 76
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2706
# Generating from seed: enberg-tm
# enberg-tm electronic works in the thing as she could not and the thing as she could not and the thing as she c==================================================
# Iteration #: 77
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2693
# Generating from seed: said in a
# said in a more complay and the dormouse short the dormouse short the dormouse short the dormouse short the dor==================================================
# Iteration #: 78
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2680
# Generating from seed: tily, afra
# tily, afrant at the end of the court way you are looked at the end of the court way you are looked at the end ==================================================
# Iteration #: 79
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2677
# Generating from seed: refund des
# refund despice. if it was an a great herself in a hereed to her hands mather creatures and the caterpillar a m==================================================
# Iteration #: 80
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2672
# Generating from seed: n off as h
# n off as he shook the door about in the project gutenberg-tm electronic works in the same thing as the project==================================================
# Iteration #: 81
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2651
# Generating from seed: ) agreemen
# ) agreement at the the top of and did not at all the grown the door and she was seemed to she did not like the==================================================
# Iteration #: 82
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2653
# Generating from seed: ted and gi
# ted and give how its the door a feat was so macket the duchess, the duchess, the duchess, the duchess, the duc==================================================
# Iteration #: 83
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2643
# Generating from seed: ere dinn m
# ere dinn made as she could not as i should the mock turtle sighere or the king, and the mouse she was the shar==================================================
# Iteration #: 84
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2631
# Generating from seed:  all? said
#  all? said alice, and she went on its like at all like to the mouse was so the trees of the mouse was so the t==================================================
# Iteration #: 85
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2617
# Generating from seed: t, now tha
# t, now that she had not as i had to like a strarge a could not the door a both she had to keested the dormouse==================================================
# Iteration #: 86
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2615
# Generating from seed:  with this
#  with this have rabbit, and the project gutenberg-tm electronic works in the project gutenberg-tm electronic w==================================================
# Iteration #: 87
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2601
# Generating from seed: person the
# person the lobster alice thought that she was you are the dormouse shouth the tried to herself, and the thistl==================================================
# Iteration #: 88
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2598
# Generating from seed:  mean what
#  mean what it was a little shrink were the trial not a sure to she was to the work with the tried and she was ==================================================
# Iteration #: 89
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2591
# Generating from seed: able in th
# able in the same thing a long to see herself she had no mine alice could not the three gardeners to a lory lik==================================================
# Iteration #: 90
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2587
# Generating from seed:  half of t
#  half of the eards of the gryphon remarked to the gryphon remarked to the gryphon remarked to the gryphon rema==================================================
# Iteration #: 91
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2574
# Generating from seed:  footman r
#  footman remarked. the poor little alice to the three gay to project gutenberg-tm electronic works an enoth ou==================================================
# Iteration #: 92
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.2566
# Generating from seed: into her f
# into her face the same as she said to the dormouse shouted the queen she was sayted to began she was sayted to==================================================
# Iteration #: 93
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2568
# Generating from seed: illar took
# illar took the little thing so the court what it was and down in a hard and the white rabbit hart its and she ==================================================
# Iteration #: 94
# Epoch 1/1
# 158773/158773 [==============================] - 6s 39us/step - loss: 1.2548
# Generating from seed: lurry of t
# lurry of the project gutenberg-tm electronic works in a lory and then a this time it as she went on easter wit==================================================
# Iteration #: 95
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.2554
# Generating from seed: n asking r
# n asking replied all alice did not like a thing been as she was so good een as she was so good een as she was ==================================================
# Iteration #: 96
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2533
# Generating from seed: as so orde
# as so orderedd your busily on the right go to see it off the fan and cleared off the white rabbit hare, she sa==================================================
# Iteration #: 97
# Epoch 1/1
# 158773/158773 [==============================] - 6s 38us/step - loss: 1.2539
# Generating from seed: d, you kno
# d, you know. i dont beginning the project gutenberg-tm electronic works in the project gutenberg-tm electronic==================================================
# Iteration #: 98
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.2547
# Generating from seed: se date: m
# se date: may things the rabbit said the dormouse shook in a his first the dormouse shook in a his first the do==================================================
# Iteration #: 99
# Epoch 1/1
# 158773/158773 [==============================] - 6s 37us/step - loss: 1.2519
# Generating from seed:  be collec
#  be collected round on the project gutenberg-tm electronic works in a hard, and said to herself, in a could to

# %% [markdown]
# # TESTING ON RAW TEXT FILE OF ALICE IN WONDERLAND (CONATINS PUBLISHER INFO, LISCENCES , GARBAGE)
# # AT 25 NUM_ITERATIONS GETTING LOSS - 1.
# # AT 35 NUM_ITERATIONS GETTING LOSS - 1.3553
# # AT 50 NUM_ITERATIONS GETTING LOSS - 1.3074
# # AT 100 NUM_ITERATIONS GETTING LOSS - 1.2519
# # (eg:Generating from seed:  be collec
# # be collected round on the project gutenberg-tm electronic works in a hard, and said to herself, in a could to)
